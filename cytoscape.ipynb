# %%
import ipycytoscape

# %%
data = {
    'nodes': [
        { 'data': { 'id': 'Myriel', 'label': 'Myriel', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Napoleon', 'label': 'Napoleon', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Mlle.Baptistine', 'label': 'Mlle.Baptistine', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Mme.Magloire', 'label': 'Mme.Magloire', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Geborand', 'label': 'Geborand', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Champtercier', 'label': 'Champtercier', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Cravatte', 'label': 'Cravatte', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'CountessdeLo', 'label': 'CountessdeLo', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } },
        { 'data': { 'id': 'Valjean', 'label': 'Valjean', 'href': 'https://github.com/jsongraph/json-graph-specification/blob/master/examples/les_miserables.json' } }
    ],
    'edges': [
        {'data': { 'source': 'Napoleon', 'target': 'Myriel' }},
        {'data': { 'source': 'Mlle.Baptistine', 'target': 'Myriel' }},
        {'data': { 'source': 'Mme.Magloire', 'target': 'Myriel' }},
        {'data': { 'source': 'Mme.Magloire', 'target': 'Mlle.Baptistine' }},
        {'data': { 'source': 'CountessdeLo', 'target': 'Myriel' }},
        {'data': { 'source': 'Geborand', 'target': 'Myriel' }},
        {'data': { 'source': 'Champtercier', 'target': 'Myriel' }},
        {'data': { 'source': 'Cravatte', 'target': 'Myriel' }},
        {'data': { 'source': 'Valjean', 'target': 'Mme.Magloire' }}
    ]
}

# %%
obj = ipycytoscape.CytoscapeWidget()
obj.graph.add_graph_from_json(data)

# %%
obj.set_style([{
                        'selector': 'node',
                        'css': {
                            'content': 'data(label)',
                            'text-valign': 'center',
                            'color': 'purple',
                            'text-outline-width': 1,
                            'text-outline-color': 'violet',
                            'background-color': 'pink',
                            'font-family': 'Century Gothic',
                            'font-size': '15px'
                        }
                        },
                        ])

# %%
obj
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'cola'}, cytoscape_style=[{'selector': 'node', 'css': {'content': 'd…
